# %% [markdown]
# <center><h1 style="text-align: center;"><u>Pruebas TFM</u></h1>
# <center><img src="https://nachocarnes.es/wp-content/uploads/2018/04/ejWGXui6_400x400.png" alt="Drawing" style="align=left"/>

# %% [markdown]
# Los datos provienen de la plataforma Kaggle,
#
# URL : https://www.kaggle.com/datasets/cdc/national-health-and-nutrition-examination-survey/data
#
# Se guardan los datos en la ruta : C:\Users\danie\OneDrive\Documentos\Master\Lusku\TFM\Pruebas\Datos

# %%
# Carga de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Se procede a hacer una carga de los datos
df_labs = pd.read_csv('Datos/labs.csv')
df_diet = pd.read_csv('Datos/diet.csv')

# %%
df_labs.info
df_diet.info
# Out:
# <bound method DataFrame.info of        SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0     73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1     73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2     73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3     73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4     73561   59052.357033   39004.892993         1      63.0    2.0     2.0
# ...     ...            ...            ...       ...       ...    ...     ...
# 9808  83727   14146.781331   10520.302070         1      59.0    2.0     2.0
# 9809  83728   38750.761193   51815.103262         1      25.0    2.0     2.0
# 9810  83729   15272.505199   10401.781170         1      59.0    2.0     2.0
# 9811  83730       0.000000            NaN         5       NaN    NaN     NaN
# 9812  83731    5805.674812    4339.132077         1      49.0    2.0     2.0
#
#       DR1DBIH  DR1DAY  DR1LANG  ...  DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0         6.0     2.0      1.0  ...       NaN      NaN       NaN      NaN
# 1         4.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
# 2        18.0     6.0      1.0  ...       NaN      NaN       NaN      NaN
# 3        21.0     3.0      1.0  ...       NaN      NaN       NaN      NaN
# 4        18.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
# ...       ...     ...      ...  ...       ...      ...       ...      ...
# 9808      8.0     7.0      1.0  ...       NaN      2.0       NaN      2.0
# 9809      9.0     5.0      1.0  ...       NaN      NaN       NaN      NaN
# 9810      1.0     6.0      1.0  ...       NaN      2.0       NaN      2.0
# 9811      NaN     NaN      NaN  ...       NaN      NaN       NaN      NaN
# 9812     12.0     6.0      1.0  ...       NaN      NaN       NaN      NaN
#
#       DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# 0          NaN      NaN       NaN      NaN       NaN      NaN
# 1          NaN      2.0       NaN      2.0       NaN      2.0
# 2          NaN      NaN       NaN      NaN       NaN      NaN
# 3          NaN      NaN       NaN      NaN       NaN      NaN
# 4          NaN      2.0       NaN      2.0       NaN      2.0
# ...        ...      ...       ...      ...       ...      ...
# 9808       NaN      2.0       NaN      2.0       NaN      2.0
# 9809       NaN      NaN       NaN      NaN       NaN      NaN
# 9810       NaN      2.0       NaN      2.0       NaN      2.0
# 9811       NaN      NaN       NaN      NaN       NaN      NaN
# 9812       NaN      NaN       NaN      NaN       NaN      NaN
#
# [9813 rows x 168 columns]>

# %%
print('Labs dataFrame Shape : ' + str(df_labs.shape))
print('Diet dataFrame Shape : ' + str(df_diet.shape))
# Out:
# Labs dataFrame Shape : (9813, 424)
# Diet dataFrame Shape : (9813, 168)

# %%
df_diet.head()
# Out:
#     SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0  73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1  73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2  73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3  73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4  73561   59052.357033   39004.892993         1      63.0    2.0     2.0
#
#    DR1DBIH  DR1DAY  DR1LANG  ...  DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0      6.0     2.0      1.0  ...       NaN      NaN       NaN      NaN
# 1      4.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
# 2     18.0     6.0      1.0  ...       NaN      NaN       NaN      NaN
# 3     21.0     3.0      1.0  ...       NaN      NaN       NaN      NaN
# 4     18.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
#
#    DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# 0       NaN      NaN       NaN      NaN       NaN      NaN
# 1       NaN      2.0       NaN      2.0       NaN      2.0
# 2       NaN      NaN       NaN      NaN       NaN      NaN
# 3       NaN      NaN       NaN      NaN       NaN      NaN
# 4       NaN      2.0       NaN      2.0       NaN      2.0
#
# [5 rows x 168 columns]

# %%
columns = df_labs.columns
columns
# Out:
# Index(['SEQN', 'URXUMA', 'URXUMS', 'URXUCR.x', 'URXCRS', 'URDACT',
#        'WTSAF2YR.x', 'LBXAPB', 'LBDAPBSI', 'LBXSAL',
#        ...
#        'URXUTL', 'URDUTLLC', 'URXUTU', 'URDUTULC', 'URXUUR', 'URDUURLC',
#        'URXPREG', 'URXUAS', 'LBDB12', 'LBDB12SI'],
#       dtype='object', length=424)

# %%
plt.figure(figsize=(24, 16))
sns.heatmap(df_labs.isnull(), cbar=False, yticklabels=False,cmap='plasma')
# Out:
# <Axes: >

# %%
correlation_matrix_labs = df_labs.corr()
# Genera un mapa de calor de la matriz de correlación
plt.figure(figsize=(24, 20))
sns.heatmap(correlation_matrix_labs, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlación del DataFrame')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **Texto en negrita**
#
# *Texto en cursiva*
#
# ~~Texto tachado~~, pero este no está tachado

# %% [markdown]
# ---
# <font color="#004D7F" size=6 style="font-family:Verdana;">Enlaces</font>

# %% [markdown]
# [Texto del enlace](https://www.example.com)
#
# [Ancla a parte del código (título Markdown)](#bloque2)

# %% [markdown]
# ![Imagen de Kschool](https://nachocarnes.es/wp-content/uploads/2018/04/ejWGXui6_400x400.png)

# %% [markdown]
# Opción 2

# %% [markdown]
# <center><img src="https://nachocarnes.es/wp-content/uploads/2018/04/ejWGXui6_400x400.png" alt="Drawing" style="align=left"/>

# %%
# !git clone https://github.com/emunozlorenzo/DataCopCrimePrediction.git
# Out:
# Cloning into 'DataCopCrimePrediction'...
# remote: Enumerating objects: 367, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 367 (delta 55), reused 58 (delta 30), pack-reused 271
# Receiving objects: 100% (367/367), 14.71 MiB | 21.93 MiB/s, done.
# Resolving deltas: 100% (188/188), done.

# %% [markdown]
# #### **Aquí os añado la referencia a una pagina donde podéis encontrar muchos más ejemplos:**
# 1. https://daringfireball.net/projects/markdown/basics
# 2. https://programmerclick.com/article/9139292621/
